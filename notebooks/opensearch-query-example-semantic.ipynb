# %% [markdown]
# # Opensearch query example
#
# This notebook serves as a fully working Opensearch query example that we can use for discussion and development before adding the constraints of request and response models and tests.
#
# There are various TODOs in here indicating some of the decisions that need to be made.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append('..')

# %%
import time
import numpy as np
from typing import Optional, List, Dict, Tuple

from app.index import OpenSearchIndex
from app.ml import SBERTEncoder

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### 1a. Connect to Opensearch
# As we're outside of docker-compose we'll connect to Opensearch via localhost.

# %%
opensearch = OpenSearchIndex(
    url="https://search-opensearch-dev-temp-nzkttufrxxmadvl37l4teezwri.eu-west-2.es.amazonaws.com",
    # url="https://search-navigator-alpha-g5fgeoght3wpmpk2jjxopbaaue.eu-west-2.es.amazonaws.com",
    username="cpr-master",
    password="fQ7c@888Etz@",
    index_name="navigator",
    # TODO: convert to env variables?
    opensearch_connector_kwargs={
        "use_ssl": True,
        "verify_certs": True,
        "ssl_show_warn": True,
    },
    embedding_dim=768,
)

print(opensearch.is_connected())

opns = opensearch.opns
# Out:
# True

# %% [markdown]
# ### 1b. Load sentence-BERT encoder
#
# This is used to generate embeddings for semantic search.

# %%
# TODO: this needs to be the same model as used for indexing. At a later stage when we start updating
# models we may want a way of ensuring both models are the same.
enc = SBERTEncoder(model_name="msmarco-distilbert-dot-v5")
enc.encode("hello world").shape
# Out:
# (768,)

# %%
emba = enc.encode("bicycle race")
embb = enc.encode("car race")
embc = enc.encode("tortoise race")

np.dot(emba, embb), np.dot(emba, embc)
# Out:
# (80.994026, 76.67018)

# %% [markdown]
# ### 2. Run search
#
# The `run_query` function does all of the heavy lifting here. See various TODOs and [issue #420](https://github.com/climatepolicyradar/navigator/issues/420) for discussion points.

# %%
def _innerproduct_threshold_to_lucene_threshold(ip_thresh: float) -> float:
    """
    Opensearch documentation on mapping similarity functions to Lucene thresholds is here: https://github.com/opensearch-project/k-NN/blob/main/src/main/java/org/opensearch/knn/index/SpaceType.java#L33
    It defines 'inner product' as negative inner product i.e. a distance rather than similarity measure, so we reverse the signs of inner product here compared to the docs.
    """
    if ip_thresh > 0:
        return ip_thresh + 1
    else:
        return 1 / (1-ip_thresh)

def _year_range_filter(year_range: Tuple[Optional[int], Optional[int]]):
    """
    Get an Opensearch filter for year range. The filter returned is between the first term of
    `year_range` and the last term, and is inclusive. Either value can be set to None to only
    apply one year constraint.
    """

    start_date = f"01/01/{year_range[0]}" if year_range[0] is not None else None
    end_date = f"31/12/{year_range[1]}" if year_range[1] is not None else None

    policy_year_conditions = {}
    if start_date is not None:
        policy_year_conditions["gte"] = start_date
    if end_date is not None:
        policy_year_conditions["lte"] = end_date

    range_filter = {"range": {}}

    range_filter["range"]["document_date"] = policy_year_conditions

    return range_filter

# %%
def run_query(
    query_string,
    max_passages_per_doc: int,
    keyword_filters: Optional[Dict[str, List[str]]] = None,
    year_range: Optional[Tuple[Optional[int], Optional[int]]] = None,
    name_boost=100, 
    description_boost=40, 
    text_boost=50, 
    innerproduct_threshold=70, 
    knn_k_value=10000,
    n_passages_to_sample_per_shard=5000, 
    max_doc_count=100,
    required_fields: Optional[List[str]] = ["document_name"]
):
    # TODO: we might want to handle encoding the query string outside of the search method?
    embedding = enc.encode(query_string)
    lucene_threshold = _innerproduct_threshold_to_lucene_threshold(innerproduct_threshold)    
    opns_query = {
                "size": 0,  # only return aggregations
                "query": {
                    "bool": {
                        "should": [{
                            "bool": {
                                "should": [
                                    {
                                        "match": {
                                            "for_search_document_name": {
                                                "query": query_string,
                                            }
                                        }
                                    },
                                    {
                                        "match_phrase": {
                                            "for_search_document_name": {
                                                "query": query_string,
                                                "boost": 2,  # TODO: configure?
                                            }
                                        }
                                    },
                                ],
                                "boost": name_boost,
                            }
                        },
                        {
                            "bool": {
                                "should": [
                                    {
                                        "match": {
                                            "for_search_document_description": {
                                                "query": query_string,
                                                "boost": 3,  # TODO: configure?
                                            }
                                        }
                                    },
                                    {
                                        "function_score": {
                                            "query": {
                                                "knn": {
                                                    "document_description_embedding": {
                                                        "vector": embedding,
                                                        "k": knn_k_value,
                                                    },
                                                },
                                            },
                                            "min_score": lucene_threshold,
                                        }
                                    },
                                ],
                                "minimum_should_match": 1,
                                "boost": description_boost,
                            },
                        },
                        {
                            "bool": {
                                "should": [
                                    {
                                        "match": {
                                            "text": {
                                                "query": query_string,
                                            },
                                        }
                                    },
                                    {
                                        "function_score": {
                                            "query": {
                                                "knn": {
                                                    "text_embedding": {
                                                        "vector": embedding,
                                                        "k": knn_k_value,
                                                    },
                                                },
                                            },
                                            "min_score": lucene_threshold,
                                        }
                                    },
                                ],
                                "minimum_should_match": 1,
                                "boost": text_boost,
                            }
                        },
                    ],
                        "minimum_should_match": 1,
                    },
                },
                "aggs": {
                    "sample": {
                        "sampler": {
                            "shard_size": n_passages_to_sample_per_shard
                        },
                        "aggs": {
                            "top_docs": {
                                "terms": {
                                    "field": "document_name_and_id",
                                    "order": {"document_date.avg": "asc"},
                                    "size": max_doc_count,
                                },
                                "aggs": {
                                    "top_passage_hits": {
                                        "top_hits": {
                                            "_source": {
                                                "excludes": [
                                                    "text_embedding",
                                                    "document_description_embedding",
                                                ]
                                            },
                                            "size": max_passages_per_doc,
                                        },
                                    },
                                    "top_hit": {"max": {"script": {"source": "_score"}}},
                                    "document_date": {
                                        "stats": {
                                            "field": "document_date",
                                        },
                                    },
                                },
                            },
                        },
                    },
                    "no_unique_docs": {"cardinality": {"field": "document_name_and_id"}},
                },
            }
    if keyword_filters:
        terms_clauses = []

        for field, values in keyword_filters.items():
            terms_clauses.append({"terms": {field: values}})

        opns_query["query"]["bool"]["filter"] = terms_clauses


    if year_range:
        if "filter" not in opns_query["query"]["bool"]:
            opns_query["query"]["bool"]["filter"] = []

        opns_query["query"]["bool"]["filter"].append(
            _year_range_filter(year_range)
        )
        
    if required_fields:
        must_clause = [
            {"exists": {"field": field_name}}
            for field_name in required_fields
        ]
        
        opns_query["query"]["bool"]["must"] = must_clause


    start = time.time()
    response = opns.search(
        body=opns_query,
        index="navigator",
        request_timeout=30,
        preference="prototype_user", # TODO: document what this means
        explain=True,
    )
    end = time.time()
    print(f"query execution time: {round(end-start, 2)}s")

    return response

run_query(
    "Energy prices", 
    max_passages_per_doc=10,
    year_range=["2017", "2022"],
    
)
# Out:
# query execution time: 1.79s
# {'took': 7,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'no_unique_docs': {'value': 519},
#   'sample': {'doc_count': 5000,
#    'top_docs': {'doc_count_error_upper_bound': -1,
#     'sum_other_doc_count': 3934,
#     'buckets': [{'key': '5-year and 20-year national development plan 12936',
#       'doc_count': 16,
#       'document_date': {'count': 16,
#        'min': 1483228800000.0,
#        'max': 1483228800000.0,
#        'avg': 1483228800000.0,
#        'sum': 23731660800000.0,
#        'min_as_string': '01/01/2017',
#        'max_as_string': '01/01/2017',
#        'avg_as_string': '01/01/2017',
#        'sum_as_string': '11/01/2722'},
#       'top_hit': {'value': 377.43115234375},
#       'top_passage_hits': {'hits': {'total': {'value': 16, 'relation': 'eq'},
#         'max_score': 377.43115,
#         'hits': [{'_index': 'navigator',
#           '_type': '_doc',
#           '_id': '718VB4EBOM4u5WteZ8v-',
#           '_score': 377.43115,
#           '_source': {'document_instrument_name': ['Research & Development, knowledge generation|Information',
#             'Education, training and knowledge dissemination|Information',
#             'Processes, plans and strategies|Governance',
#             'Capacity building|Governance',
#             'Early warning systems|Direct Investment',
#             'Tax incentives|Economic',
#             'Standards, obligations and norms|Regulation'],
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'East Asia & Pacific',
#            'document_description': 'Fiji has both a 20-Year Development Plan (2017-2036) and a comprehensive 5-Year Development Plan (2017-2021). These plans work together as the&nbsp;5-Year Development Plan provides a detailed action agenda with specific targets and policies that are aligned to the long-term transformational 20-Year Development Plan.<br><br>The National Development Plan (NDP) shares an inclusive socio-economic development and the strategies within are designed to empower every Fijian and widen the reach of programmes, services and networks of infrastructure to transform Fiji.&nbsp;<br><br>The NDP tackles critical cross-cutting issues such as climate change, green growth, the environment, gender equality, disability and governance.',
#            'document_country_english_shortname': 'Fiji',
#            'document_category': 'Policy',
#            'document_sector_name': ['Transportation',
#             'Industry',
#             'Economy-wide',
#             'Buildings',
#             'Agriculture'],
#            'md5_sum': 'a6ccce710ab644726d6025a70811d08c',
#            'document_language': 'English',
#            'document_id': 12936,
#            'document_source_name': 'CCLW',
#            'document_name': '5-Year and 20-Year National Development Plan',
#            'document_country_code': 'FJI',
#            'document_hazard_name': ['Landslides',
#             'Erosion',
#             'Drought',
#             'Flood'],
#            'text': 'underpinned by lower prices of food, clothing and',
#            'document_response_name': ['Mitigation', 'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'East Asia & Pacific',
#            'text_block_id': 'p16_b508',
#            'document_source_url': 'https://climate-laws.org/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc2NNIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--5e742f26b59d59ab40c95b452459b45a85bd7f84/2017%20Fiji%205-Year%20and%2020-Year%20National%20Development%20Plan.pdf',
#            'document_date': '01/01/2017',
#            'text_block_page': 16,
#            'text_block_coords': [[304.7243957519531, 418.602294921875],
#             [508.6043701171875, 418.602294921875],
#             [508.6043701171875, 431.6522979736328],
#             [304.7243957519531, 431.6522979736328]],
#            'document_name_and_id': '5-Year and 20-Year National Development Plan 12936',
#            'document_keyword': ['Industry',
#             'Buildings',
#             'Transport',
#             'Agriculture'],
#            'document_url': 'https://cdn.climatepolicyradar.org/FJI/2017/FJI-2017-01-01-5-Year and 20-Year National Development Plan_a6ccce710ab644726d6025a70811d08c.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': '3F8VB4EBOM4u5WteZ8v-',
#           '_score': 346.95868,
#           '_source': {'document_instrument_name': ['Research & Development, knowledge generation|Information',
#             'Education, training and knowledge dissemination|Information',
#             'Processes, plans and strategies|Governance',
#             'Capacity building|Governance',
#             'Early warning systems|Direct Investment',
#             'Tax incentives|Economic',
#             'Standards, obligations and norms|Regulation'],
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'East Asia & Pacific',
#            'document_description': 'Fiji has both a 20-Year Development Plan (2017-2036) and a comprehensive 5-Year Development Plan (2017-2021). These plans work together as the&nbsp;5-Year Development Plan provides a detailed action agenda with specific targets and policies that are aligned to the long-term transformational 20-Year Development Plan.<br><br>The National Development Plan (NDP) shares an inclusive socio-economic development and the strategies within are designed to empower every Fijian and widen the reach of programmes, services and networks of infrastructure to transform Fiji.&nbsp;<br><br>The NDP tackles critical cross-cutting issues such as climate change, green growth, the environment, gender equality, disability and governance.',
#            'document_country_english_shortname': 'Fiji',
#            'document_category': 'Policy',
#            'document_sector_name': ['Transportation',
#             'Industry',
#             'Economy-wide',
#             'Buildings',
#             'Agriculture'],
#            'md5_sum': 'a6ccce710ab644726d6025a70811d08c',
#            'document_language': 'English',
#            'document_id': 12936,
#            'document_source_name': 'CCLW',
#            'document_name': '5-Year and 20-Year National Development Plan',
#            'document_country_code': 'FJI',
#            'document_hazard_name': ['Landslides',
#             'Erosion',
#             'Drought',
#             'Flood'],
#            'text': 'of positive global developments. Oil prices have been low, although rising slowly recently. Fiji’s major trading partners are performing relatively well. The prospects',
#            'document_response_name': ['Mitigation', 'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'East Asia & Pacific',
#            'text_block_id': 'p16_b489',
#            'document_source_url': 'https://climate-laws.org/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc2NNIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--5e742f26b59d59ab40c95b452459b45a85bd7f84/2017%20Fiji%205-Year%20and%2020-Year%20National%20Development%20Plan.pdf',
#            'document_date': '01/01/2017',
#            'text_block_page': 16,
#            'text_block_coords': [[56.692901611328125, 132.9080047607422],
#             [278.25286865234375, 132.9080047607422],
#             [278.25286865234375, 169.95799255371094],
#             [56.692901611328125, 169.95799255371094]],
#            'document_name_and_id': '5-Year and 20-Year National Development Plan 12936',
#            'document_keyword': ['Industry',
#             'Buildings',
#             'Transport',
#             'Agriculture'],
#            'document_url': 'https://cdn.climatepolicyradar.org/FJI/2017/FJI-2017-01-01-5-Year and 20-Year National Development Plan_a6ccce710ab644726d6025a70811d08c.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': '818VB4EBOM4u5WteZ8z-',
#           '_score': 306.1482,
#           '_source': {'document_instrument_name': ['Research & Development, knowledge generation|Information',
#             'Education, training and knowledge dissemination|Information',
#             'Processes, plans and strategies|Governance',
#             'Capacity building|Governance',
#             'Early warning systems|Direct Investment',
#             'Tax incentives|Economic',
#             'Standards, obligations and norms|Regulation'],
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'East Asia & Pacific',
#            'document_description': 'Fiji has both a 20-Year Development Plan (2017-2036) and a comprehensive 5-Year Development Plan (2017-2021). These plans work together as the&nbsp;5-Year Development Plan provides a detailed action agenda with specific targets and policies that are aligned to the long-term transformational 20-Year Development Plan.<br><br>The National Development Plan (NDP) shares an inclusive socio-economic development and the strategies within are designed to empower every Fijian and widen the reach of programmes, services and networks of infrastructure to transform Fiji.&nbsp;<br><br>The NDP tackles critical cross-cutting issues such as climate change, green growth, the environment, gender equality, disability and governance.',
#            'document_country_english_shortname': 'Fiji',
#            'document_category': 'Policy',
#            'document_sector_name': ['Transportation',
#             'Industry',
#             'Economy-wide',
#             'Buildings',
#             'Agriculture'],
#            'md5_sum': 'a6ccce710ab644726d6025a70811d08c',
#            'document_language': 'English',
#            'document_id': 12936,
#            'document_source_name': 'CCLW',
#            'document_name': '5-Year and 20-Year National Development Plan',
#            'document_country_code': 'FJI',
#            'document_hazard_name': ['Landslides',
#             'Erosion',
#             'Drought',
#             'Flood'],
#            'text': 'energy and the generation of energy from waste.',
#            'document_response_name': ['Mitigation', 'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'East Asia & Pacific',
#            'text_block_id': 'p29_b797',
#            'document_source_url': 'https://climate-laws.org/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc2NNIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--5e742f26b59d59ab40c95b452459b45a85bd7f84/2017%20Fiji%205-Year%20and%2020-Year%20National%20Development%20Plan.pdf',
#            'document_date': '01/01/2017',
#            'text_block_page': 29,
#            'text_block_coords': [[56.692901611328125, 245.67909240722656],
#             [253.98789978027344, 245.67909240722656],
#             [253.98789978027344, 258.7290954589844],
#             [56.692901611328125, 258.7290954589844]],
#            'document_name_and_id': '5-Year and 20-Year National Development Plan 12936',
#            'document_keyword': ['Industry',
#             'Buildings',
#             'Transport',
#             'Agriculture'],
#            'document_url': 'https://cdn.climatepolicyradar.org/FJI/2017/FJI-2017-01-01-5-Year and 20-Year National Development Plan_a6ccce710ab644726d6025a70811d08c.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': 'EF8VB4EBOM4u5WteZ83-',
#           '_score': 297.7541,
#           '_source': {'document_instrument_name': ['Research & Development, knowledge generation|Information',
#             'Education, training and knowledge dissemination|Information',
#             'Processes, plans and strategies|Governance',
#             'Capacity building|Governance',
#             'Early warning systems|Direct Investment',
#             'Tax incentives|Economic',
#             'Standards, obligations and norms|Regulation'],
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'East Asia & Pacific',
#            'document_description': 'Fiji has both a 20-Year Development Plan (2017-2036) and a comprehensive 5-Year Development Plan (2017-2021). These plans work together as the&nbsp;5-Year Development Plan provides a detailed action agenda with specific targets and policies that are aligned to the long-term transformational 20-Year Development Plan.<br><br>The National Development Plan (NDP) shares an inclusive socio-economic development and the strategies within are designed to empower every Fijian and widen the reach of programmes, services and networks of infrastructure to transform Fiji.&nbsp;<br><br>The NDP tackles critical cross-cutting issues such as climate change, green growth, the environment, gender equality, disability and governance.',
#            'document_country_english_shortname': 'Fiji',
#            'document_category': 'Policy',
#            'document_sector_name': ['Transportation',
#             'Industry',
#             'Economy-wide',
#             'Buildings',
#             'Agriculture'],
#            'md5_sum': 'a6ccce710ab644726d6025a70811d08c',
#            'document_language': 'English',
#            'document_id': 12936,
#            'document_source_name': 'CCLW',
#            'document_name': '5-Year and 20-Year National Development Plan',
#            'document_country_code': 'FJI',
#            'document_hazard_name': ['Landslides',
#             'Erosion',
#             'Drought',
#             'Flood'],
#            'text': 'energy resources.',
#            'document_response_name': ['Mitigation', 'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'East Asia & Pacific',
#            'text_block_id': 'p29_b826',
#            'document_source_url': 'https://climate-laws.org/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc2NNIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--5e742f26b59d59ab40c95b452459b45a85bd7f84/2017%20Fiji%205-Year%20and%2020-Year%20National%20Development%20Plan.pdf',
#            'document_date': '01/01/2017',
#            'text_block_page': 29,
#            'text_block_coords': [[304.722900390625, 423.0390930175781],
#             [376.00689697265625, 423.0390930175781],
#             [376.00689697265625, 436.08909606933594],
#             [304.722900390625, 436.08909606933594]],
#            'document_name_and_id': '5-Year and 20-Year National Development Plan 12936',
#            'document_keyword': ['Industry',
#             'Buildings',
#             'Transport',
#             'Agriculture'],
#            'document_url': 'https://cdn.climatepolicyradar.org/FJI/2017/FJI-2017-01-01-5-Year and 20-Year National Development Plan_a6ccce710ab644726d6025a70811d08c.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': '3V8VB4EBOM4u5WteZ8z-',
#           '_score': 292.88037,
#           '_source': {'document_instrument_name': ['Research & Development, knowledge generation|Information',
#             'Education, training and knowledge dissemination|Information',
#             'Processes, plans and strategies|Governance',
#             'Capacity building|Governance',
#             'Early warning systems|Direct Investment',
#             'Tax incentives|Economic',
#             'Standards, obligations and norms|Regulation'],
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'East Asia & Pacific',
#            'document_description': 'Fiji has both a 20-Year Development Plan (2017-2036) and a comprehensive 5-Year Development Plan (2017-2021). These plans work together as the&nbsp;5-Year Development Plan provides a detailed action agenda with specific targets and policies that are aligned to the long-term transformational 20-Year Development Plan.<br><br>The National Development Plan (NDP) shares an inclusive socio-economic development and the strategies within are designed to empower every Fijian and widen the reach of programmes, services and networks of infrastructure to transform Fiji.&nbsp;<br><br>The NDP tackles critical cross-cutting issues such as climate change, green growth, the environment, gender equality, disability and governance.',
#            'document_country_english_shortname': 'Fiji',
#            'document_category': 'Policy',
#            'document_sector_name': ['Transportation',
#             'Industry',
#             'Economy-wide',
#             'Buildings',
#             'Agriculture'],
#            'md5_sum': 'a6ccce710ab644726d6025a70811d08c',
#            'document_language': 'English',
#            'document_id': 12936,
#            'document_source_name': 'CCLW',
#            'document_name': '5-Year and 20-Year National Development Plan',
#            'document_country_code': 'FJI',
#            'document_hazard_name': ['Landslides',
#             'Erosion',
#             'Drought',
#             'Flood'],
#            'text': '3.1.2 ENERGY',
#            'document_response_name': ['Mitigation', 'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'East Asia & Pacific',
#            'text_block_id': 'p29_b775',
#            'document_source_url': 'https://climate-laws.org/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc2NNIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--5e742f26b59d59ab40c95b452459b45a85bd7f84/2017%20Fiji%205-Year%20and%2020-Year%20National%20Development%20Plan.pdf',
#            'document_date': '01/01/2017',
#            'text_block_page': 29,
#            'text_block_coords': [[56.692901611328125, 771.1829986572266],
#             [150.20191955566406, 771.1829986572266],
#             [150.20191955566406, 786.7440032958984],
#             [56.692901611328125, 786.7440032958984]],
#            'document_name_and_id': '5-Year and 20-Year National Development Plan 12936',
#            'document_keyword': ['Industry',
#             'Buildings',
#             'Transport',
#             'Agriculture'],
#            'document_url': 'https://cdn.climatepolicyradar.org/FJI/2017/FJI-2017-01-01-5-Year and 20-Year National Development Plan_a6ccce710ab644726d6025a70811d08c.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': 'DV8VB4EBOM4u5WteZ83-',
#           '_score': 288.72253,
#           '_source': {'document_instrument_name': ['Research & Development, knowledge generation|Information',
#             'Education, training and knowledge dissemination|Information',
#             'Processes, plans and strategies|Governance',
#             'Capacity building|Governance',
#             'Early warning systems|Direct Investment',
#             'Tax incentives|Economic',
#             'Standards, obligations and norms|Regulation'],
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'East Asia & Pacific',
#            'document_description': 'Fiji has both a 20-Year Development Plan (2017-2036) and a comprehensive 5-Year Development Plan (2017-2021). These plans work together as the&nbsp;5-Year Development Plan provides a detailed action agenda with specific targets and policies that are aligned to the long-term transformational 20-Year Development Plan.<br><br>The National Development Plan (NDP) shares an inclusive socio-economic development and the strategies within are designed to empower every Fijian and widen the reach of programmes, services and networks of infrastructure to transform Fiji.&nbsp;<br><br>The NDP tackles critical cross-cutting issues such as climate change, green growth, the environment, gender equality, disability and governance.',
#            'document_country_english_shortname': 'Fiji',
#            'document_category': 'Policy',
#            'document_sector_name': ['Transportation',
#             'Industry',
#             'Economy-wide',
#             'Buildings',
#             'Agriculture'],
#            'md5_sum': 'a6ccce710ab644726d6025a70811d08c',
#            'document_language': 'English',
#            'document_id': 12936,
#            'document_source_name': 'CCLW',
#            'document_name': '5-Year and 20-Year National Development Plan',
#            'document_country_code': 'FJI',
#            'document_hazard_name': ['Landslides',
#             'Erosion',
#             'Drought',
#             'Flood'],
#            'text': 'renewable energy systems.',
#            'document_response_name': ['Mitigation', 'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'East Asia & Pacific',
#            'text_block_id': 'p29_b823',
#            'document_source_url': 'https://climate-laws.org/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc2NNIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--5e742f26b59d59ab40c95b452459b45a85bd7f84/2017%20Fiji%205-Year%20and%2020-Year%20National%20Development%20Plan.pdf',
#            'document_date': '01/01/2017',
#            'text_block_page': 29,
#            'text_block_coords': [[304.722900390625, 469.0390930175781],
#             [412.45689392089844, 469.0390930175781],
#             [412.45689392089844, 482.08909606933594],
#             [304.722900390625, 482.08909606933594]],
#            'document_name_and_id': '5-Year and 20-Year National Development Plan 12936',
#            'document_keyword': ['Industry',
#             'Buildings',
#             'Transport',
#             'Agriculture'],
#            'document_url': 'https://cdn.climatepolicyradar.org/FJI/2017/FJI-2017-01-01-5-Year and 20-Year National Development Plan_a6ccce710ab644726d6025a70811d08c.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': 'n8UVB4EBLpAxSYvydwMv',
#           '_score': 287.72092,
#           '_source': {'document_instrument_name': ['Research & Development, knowledge generation|Information',
#             'Education, training and knowledge dissemination|Information',
#             'Processes, plans and strategies|Governance',
#             'Capacity building|Governance',
#             'Early warning systems|Direct Investment',
#             'Tax incentives|Economic',
#             'Standards, obligations and norms|Regulation'],
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'East Asia & Pacific',
#            'document_description': 'Fiji has both a 20-Year Development Plan (2017-2036) and a comprehensive 5-Year Development Plan (2017-2021). These plans work together as the&nbsp;5-Year Development Plan provides a detailed action agenda with specific targets and policies that are aligned to the long-term transformational 20-Year Development Plan.<br><br>The National Development Plan (NDP) shares an inclusive socio-economic development and the strategies within are designed to empower every Fijian and widen the reach of programmes, services and networks of infrastructure to transform Fiji.&nbsp;<br><br>The NDP tackles critical cross-cutting issues such as climate change, green growth, the environment, gender equality, disability and governance.',
#            'document_country_english_shortname': 'Fiji',
#            'document_category': 'Policy',
#            'document_sector_name': ['Transportation',
#             'Industry',
#             'Economy-wide',
#             'Buildings',
#             'Agriculture'],
#            'md5_sum': 'a6ccce710ab644726d6025a70811d08c',
#            'document_language': 'English',
#            'document_id': 12936,
#            'document_source_name': 'CCLW',
#            'document_name': '5-Year and 20-Year National Development Plan',
#            'document_country_code': 'FJI',
#            'document_hazard_name': ['Landslides',
#             'Erosion',
#             'Drought',
#             'Flood'],
#            'text': 'renewable energy production.',
#            'document_response_name': ['Mitigation', 'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'East Asia & Pacific',
#            'text_block_id': 'p123_b1686',
#            'document_source_url': 'https://climate-laws.org/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc2NNIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--5e742f26b59d59ab40c95b452459b45a85bd7f84/2017%20Fiji%205-Year%20and%2020-Year%20National%20Development%20Plan.pdf',
#            'document_date': '01/01/2017',
#            'text_block_page': 123,
#            'text_block_coords': [[56.69140625, 586.5830993652344],
#             [178.8014678955078, 586.5830993652344],
#             [178.8014678955078, 599.6331024169922],
#             [56.69140625, 599.6331024169922]],
#            'document_name_and_id': '5-Year and 20-Year National Development Plan 12936',
#            'document_keyword': ['Industry',
#             'Buildings',
#             'Transport',
#             'Agriculture'],
#            'document_url': 'https://cdn.climatepolicyradar.org/FJI/2017/FJI-2017-01-01-5-Year and 20-Year National Development Plan_a6ccce710ab644726d6025a70811d08c.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': '318VB4EBOM4u5WteZ8z-',
#           '_score': 283.30887,
#           '_source': {'document_instrument_name': ['Research & Development, knowledge generation|Information',
#             'Education, training and knowledge dissemination|Information',
#             'Processes, plans and strategies|Governance',
#             'Capacity building|Governance',
#             'Early warning systems|Direct Investment',
#             'Tax incentives|Economic',
#             'Standards, obligations and norms|Regulation'],
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'East Asia & Pacific',
#            'document_description': 'Fiji has both a 20-Year Development Plan (2017-2036) and a comprehensive 5-Year Development Plan (2017-2021). These plans work together as the&nbsp;5-Year Development Plan provides a detailed action agenda with specific targets and policies that are aligned to the long-term transformational 20-Year Development Plan.<br><br>The National Development Plan (NDP) shares an inclusive socio-economic development and the strategies within are designed to empower every Fijian and widen the reach of programmes, services and networks of infrastructure to transform Fiji.&nbsp;<br><br>The NDP tackles critical cross-cutting issues such as climate change, green growth, the environment, gender equality, disability and governance.',
#            'document_country_english_shortname': 'Fiji',
#            'document_category': 'Policy',
#            'document_sector_name': ['Transportation',
#             'Industry',
#             'Economy-wide',
#             'Buildings',
#             'Agriculture'],
#            'md5_sum': 'a6ccce710ab644726d6025a70811d08c',
#            'document_language': 'English',
#            'document_id': 12936,
#            'document_source_name': 'CCLW',
#            'document_name': '5-Year and 20-Year National Development Plan',
#            'document_country_code': 'FJI',
#            'document_hazard_name': ['Landslides',
#             'Erosion',
#             'Drought',
#             'Flood'],
#            'text': 'environmentally sustainable energy sector”',
#            'document_response_name': ['Mitigation', 'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'East Asia & Pacific',
#            'text_block_id': 'p29_b777',
#            'document_source_url': 'https://climate-laws.org/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc2NNIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--5e742f26b59d59ab40c95b452459b45a85bd7f84/2017%20Fiji%205-Year%20and%2020-Year%20National%20Development%20Plan.pdf',
#            'document_date': '01/01/2017',
#            'text_block_page': 29,
#            'text_block_coords': [[56.692901611328125, 718.7830963134766],
#             [261.12977600097656, 718.7830963134766],
#             [261.12977600097656, 749.8390960693359],
#             [56.692901611328125, 749.8390960693359]],
#            'document_name_and_id': '5-Year and 20-Year National Development Plan 12936',
#            'document_keyword': ['Industry',
#             'Buildings',
#             'Transport',
#             'Agriculture'],
#            'document_url': 'https://cdn.climatepolicyradar.org/FJI/2017/FJI-2017-01-01-5-Year and 20-Year National Development Plan_a6ccce710ab644726d6025a70811d08c.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': 'Z8UVB4EBLpAxSYvydwMv',
#           '_score': 280.80795,
#           '_source': {'document_instrument_name': ['Research & Development, knowledge generation|Information',
#             'Education, training and knowledge dissemination|Information',
#             'Processes, plans and strategies|Governance',
#             'Capacity building|Governance',
#             'Early warning systems|Direct Investment',
#             'Tax incentives|Economic',
#             'Standards, obligations and norms|Regulation'],
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'East Asia & Pacific',
#            'document_description': 'Fiji has both a 20-Year Development Plan (2017-2036) and a comprehensive 5-Year Development Plan (2017-2021). These plans work together as the&nbsp;5-Year Development Plan provides a detailed action agenda with specific targets and policies that are aligned to the long-term transformational 20-Year Development Plan.<br><br>The National Development Plan (NDP) shares an inclusive socio-economic development and the strategies within are designed to empower every Fijian and widen the reach of programmes, services and networks of infrastructure to transform Fiji.&nbsp;<br><br>The NDP tackles critical cross-cutting issues such as climate change, green growth, the environment, gender equality, disability and governance.',
#            'document_country_english_shortname': 'Fiji',
#            'document_category': 'Policy',
#            'document_sector_name': ['Transportation',
#             'Industry',
#             'Economy-wide',
#             'Buildings',
#             'Agriculture'],
#            'md5_sum': 'a6ccce710ab644726d6025a70811d08c',
#            'document_language': 'English',
#            'document_id': 12936,
#            'document_source_name': 'CCLW',
#            'document_name': '5-Year and 20-Year National Development Plan',
#            'document_country_code': 'FJI',
#            'document_hazard_name': ['Landslides',
#             'Erosion',
#             'Drought',
#             'Flood'],
#            'text': 'provide financial assistance to domestic fishing companies through the Tuna Stabilisation Fund. To obtain premium prices in export markets, certification for sustainable',
#            'document_response_name': ['Mitigation', 'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'East Asia & Pacific',
#            'text_block_id': 'p117_b1626',
#            'document_source_url': 'https://climate-laws.org/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc2NNIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--5e742f26b59d59ab40c95b452459b45a85bd7f84/2017%20Fiji%205-Year%20and%2020-Year%20National%20Development%20Plan.pdf',
#            'document_date': '01/01/2017',
#            'text_block_page': 117,
#            'text_block_coords': [[304.722900390625, 705.0429992675781],
#             [537.8018341064453, 705.0429992675781],
#             [537.8018341064453, 742.0930023193359],
#             [304.722900390625, 742.0930023193359]],
#            'document_name_and_id': '5-Year and 20-Year National Development Plan 12936',
#            'document_keyword': ['Industry',
#             'Buildings',
#             'Transport',
#             'Agriculture'],
#            'document_url': 'https://cdn.climatepolicyradar.org/FJI/2017/FJI-2017-01-01-5-Year and 20-Year National Development Plan_a6ccce710ab644726d6025a70811d08c.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': 'BMUVB4EBLpAxSYvyXAKl',
#           '_score': 277.51678,
#           '_source': {'document_instrument_name': ['Research & Development, knowledge generation|Information',
#             'Education, training and knowledge dissemination|Information',
#             'Processes, plans and strategies|Governance',
#             'Capacity building|Governance',
#             'Early warning systems|Direct Investment',
#             'Tax incentives|Economic',
#             'Standards, obligations and norms|Regulation'],
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'East Asia & Pacific',
#            'document_description': 'Fiji has both a 20-Year Development Plan (2017-2036) and a comprehensive 5-Year Development Plan (2017-2021). These plans work together as the&nbsp;5-Year Development Plan provides a detailed action agenda with specific targets and policies that are aligned to the long-term transformational 20-Year Development Plan.<br><br>The National Development Plan (NDP) shares an inclusive socio-economic development and the strategies within are designed to empower every Fijian and widen the reach of programmes, services and networks of infrastructure to transform Fiji.&nbsp;<br><br>The NDP tackles critical cross-cutting issues such as climate change, green growth, the environment, gender equality, disability and governance.',
#            'document_country_english_shortname': 'Fiji',
#            'document_category': 'Policy',
#            'document_sector_name': ['Transportation',
#             'Industry',
#             'Economy-wide',
#             'Buildings',
#             'Agriculture'],
#            'md5_sum': 'a6ccce710ab644726d6025a70811d08c',
#            'document_language': 'English',
#            'document_id': 12936,
#            'document_source_name': 'CCLW',
#            'document_name': '5-Year and 20-Year National Development Plan',
#            'document_country_code': 'FJI',
#            'document_hazard_name': ['Landslides',
#             'Erosion',
#             'Drought',
#             'Flood'],
#            'text': 'Other renewable energy sources such as wind, solar, biomass, geothermal and wave and tidal energy will be',
#            'document_response_name': ['Mitigation', 'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'East Asia & Pacific',
#            'text_block_id': 'p7_b131',
#            'document_source_url': 'https://climate-laws.org/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc2NNIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--5e742f26b59d59ab40c95b452459b45a85bd7f84/2017%20Fiji%205-Year%20and%2020-Year%20National%20Development%20Plan.pdf',
#            'document_date': '01/01/2017',
#            'text_block_page': 7,
#            'text_block_coords': [[304.7239990234375, 174.03810119628906],
#             [526.196044921875, 174.03810119628906],
#             [526.196044921875, 199.08810424804688],
#             [304.7239990234375, 199.08810424804688]],
#            'document_name_and_id': '5-Year and 20-Year National Development Plan 12936',
#            'document_keyword': ['Industry',
#             'Buildings',
#             'Transport',
#             'Agriculture'],
#            'document_url': 'https://cdn.climatepolicyradar.org/FJI/2017/FJI-2017-01-01-5-Year and 20-Year National Development Plan_a6ccce710ab644726d6025a70811d08c.pdf'}}]}}},
#      {'key': 'afghanistan national peace and development framework (anpdf) 2017-2021 11539',
#       'doc_count': 3,
#       'document_date': {'count': 3,
#        'min': 1483228800000.0,
#        'max': 1483228800000.0,
#        'avg': 1483228800000.0,
#        'sum': 4449686400000.0,
#        'min_as_string': '01/01/2017',
#        'max_as_string': '01/01/2017',
#        'avg_as_string': '01/01/2017',
#        'sum_as_string': '03/01/2111'},
#       'top_hit': {'value': 250.8809051513672},
#       'top_passage_hits': {'hits': {'total': {'value': 3, 'relation': 'eq'},
#         'max_score': 250.8809,
#         'hits': [{'_index': 'navigator',
#           '_type': '_doc',
#           '_id': 'PxD4BoEBdV_HkmO8qWOd',
#           '_score': 250.8809,
#           '_source': {'document_instrument_name': ['Subnational and citizen participation|Governance',
#             'Capacity building|Governance',
#             'Tax incentives|Economic'],
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'South Asia',
#            'document_description': 'The Afghanistan National Peace and Development Framework (ANPDF) is a five-year strategic plan for achieving self-reliance. The Framework presents a long-term development&nbsp; for Afghanistan by providing consistent high-level guidance to government and stakeholders. It articulates immediate and long term development priorities, highlights key reforms and outlines priority investments needed to achieve development goals.<br><br>It sets the economic, political and security context to ensure the development of agriculture, extractive industries and trade.&nbsp;<br><br>The Framework establishes measures to mitigate the effects of climate change, notably in the energy sector but also by expanding agroforestry and reforestation to support environmental conservation and income generation for farmers. It also creates strategies to mitigate the adverse effects of climate change across the trans-Himalayan region.',
#            'document_country_english_shortname': 'Afghanistan',
#            'document_category': 'Policy',
#            'document_sector_name': ['Water',
#             'Waste',
#             'Health',
#             'Energy',
#             'Economy-wide',
#             'Agriculture'],
#            'md5_sum': '8933f24fb14341efc0bbbc526071ea0d',
#            'document_language': 'English',
#            'document_id': 11539,
#            'document_source_name': 'CCLW',
#            'document_name': 'Afghanistan National Peace and Development Framework (ANPDF) 2017-2021',
#            'document_country_code': 'AFG',
#            'document_hazard_name': 'Flood',
#            'text': 'Our objectives for the electricity and energy sectors are to',
#            'document_response_name': ['Mitigation',
#             'Disaster Risk Management',
#             'Adaptation'],
#            'document_type': 'Framework',
#            'document_framework_name': [],
#            'document_region_code': 'South Asia',
#            'text_block_id': 'p27_b945',
#            'document_source_url': 'https://climate-laws.org/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc29NIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--48d0073268aa0e33ef0772fc9d931cc218dd5fbf/ANPDFEnglishWebsite.pdf',
#            'document_date': '01/01/2017',
#            'text_block_page': 27,
#            'text_block_coords': [[65.19679260253906, 660.1690979003906],
#             [281.5828857421875, 660.1690979003906],
#             [281.5828857421875, 670.9691009521484],
#             [65.19679260253906, 670.9691009521484]],
#            'document_name_and_id': 'Afghanistan National Peace and Development Framework (ANPDF) 2017-2021 11539',
#            'document_keyword': ['Health', 'Taxes', 'Energy', 'Forest'],
#            'document_url': 'https://cdn.climatepolicyradar.org/AFG/2017/AFG-2017-01-01-Afghanistan National Peace and Development Framework (ANPDF) 2017-2021_8933f24fb14341efc0bbbc526071ea0d.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': 'UxD4BoEBdV_HkmO8qWOd',
#           '_score': 236.46388,
#           '_source': {'document_instrument_name': ['Subnational and citizen participation|Governance',
#             'Capacity building|Governance',
#             'Tax incentives|Economic'],
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'South Asia',
#            'document_description': 'The Afghanistan National Peace and Development Framework (ANPDF) is a five-year strategic plan for achieving self-reliance. The Framework presents a long-term development&nbsp; for Afghanistan by providing consistent high-level guidance to government and stakeholders. It articulates immediate and long term development priorities, highlights key reforms and outlines priority investments needed to achieve development goals.<br><br>It sets the economic, political and security context to ensure the development of agriculture, extractive industries and trade.&nbsp;<br><br>The Framework establishes measures to mitigate the effects of climate change, notably in the energy sector but also by expanding agroforestry and reforestation to support environmental conservation and income generation for farmers. It also creates strategies to mitigate the adverse effects of climate change across the trans-Himalayan region.',
#            'document_country_english_shortname': 'Afghanistan',
#            'document_category': 'Policy',
#            'document_sector_name': ['Water',
#             'Waste',
#             'Health',
#             'Energy',
#             'Economy-wide',
#             'Agriculture'],
#            'md5_sum': '8933f24fb14341efc0bbbc526071ea0d',
#            'document_language': 'English',
#            'document_id': 11539,
#            'document_source_name': 'CCLW',
#            'document_name': 'Afghanistan National Peace and Development Framework (ANPDF) 2017-2021',
#            'document_country_code': 'AFG',
#            'document_hazard_name': 'Flood',
#            'text': 'Increase domestic generation to 2,300 MW, using natural gas, renewable energy, and hydro-electricity',
#            'document_response_name': ['Mitigation',
#             'Disaster Risk Management',
#             'Adaptation'],
#            'document_type': 'Framework',
#            'document_framework_name': [],
#            'document_region_code': 'South Asia',
#            'text_block_id': 'p27_b965',
#            'document_source_url': 'https://climate-laws.org/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc29NIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--48d0073268aa0e33ef0772fc9d931cc218dd5fbf/ANPDFEnglishWebsite.pdf',
#            'document_date': '01/01/2017',
#            'text_block_page': 27,
#            'text_block_coords': [[87.93080139160156, 511.93910217285156],
#             [455.11817932128906, 511.93910217285156],
#             [455.11817932128906, 522.7391052246094],
#             [87.93080139160156, 522.7391052246094]],
#            'document_name_and_id': 'Afghanistan National Peace and Development Framework (ANPDF) 2017-2021 11539',
#            'document_keyword': ['Health', 'Taxes', 'Energy', 'Forest'],
#            'document_url': 'https://cdn.climatepolicyradar.org/AFG/2017/AFG-2017-01-01-Afghanistan National Peace and Development Framework (ANPDF) 2017-2021_8933f24fb14341efc0bbbc526071ea0d.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': '5sL4BoEBLpAxSYvyosZD',
#           '_score': 214.31937,
#           '_source': {'document_instrument_name': ['Subnational and citizen participation|Governance',
#             'Capacity building|Governance',
#             'Tax incentives|Economic'],
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'South Asia',
#            'document_description': 'The Afghanistan National Peace and Development Framework (ANPDF) is a five-year strategic plan for achieving self-reliance. The Framework presents a long-term development&nbsp; for Afghanistan by providing consistent high-level guidance to government and stakeholders. It articulates immediate and long term development priorities, highlights key reforms and outlines priority investments needed to achieve development goals.<br><br>It sets the economic, political and security context to ensure the development of agriculture, extractive industries and trade.&nbsp;<br><br>The Framework establishes measures to mitigate the effects of climate change, notably in the energy sector but also by expanding agroforestry and reforestation to support environmental conservation and income generation for farmers. It also creates strategies to mitigate the adverse effects of climate change across the trans-Himalayan region.',
#            'document_country_english_shortname': 'Afghanistan',
#            'document_category': 'Policy',
#            'document_sector_name': ['Water',
#             'Waste',
#             'Health',
#             'Energy',
#             'Economy-wide',
#             'Agriculture'],
#            'md5_sum': '8933f24fb14341efc0bbbc526071ea0d',
#            'document_language': 'English',
#            'document_id': 11539,
#            'document_source_name': 'CCLW',
#            'document_name': 'Afghanistan National Peace and Development Framework (ANPDF) 2017-2021',
#            'document_country_code': 'AFG',
#            'document_hazard_name': 'Flood',
#            'text': 'previous expectations for high returns to mining were over-ambitious, investments in extractive industries will eventually form a core building block for sustainable growth. Large scale investments in mining are likely to be delayed while global prices remain low.',
#            'document_response_name': ['Mitigation',
#             'Disaster Risk Management',
#             'Adaptation'],
#            'document_type': 'Framework',
#            'document_framework_name': [],
#            'document_region_code': 'South Asia',
#            'text_block_id': 'p9_b194',
#            'document_source_url': 'https://climate-laws.org/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBc29NIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--48d0073268aa0e33ef0772fc9d931cc218dd5fbf/ANPDFEnglishWebsite.pdf',
#            'document_date': '01/01/2017',
#            'text_block_page': 9,
#            'text_block_coords': [[56.692901611328125, 687.4044036865234],
#             [557.4907684326172, 687.4044036865234],
#             [557.4907684326172, 709.00439453125],
#             [56.692901611328125, 709.00439453125]],
#            'document_name_and_id': 'Afghanistan National Peace and Development Framework (ANPDF) 2017-2021 11539',
#            'document_keyword': ['Health', 'Taxes', 'Energy', 'Forest'],
#            'document_url': 'https://cdn.climatepolicyradar.org/AFG/2017/AFG-2017-01-01-Afghanistan National Peace and Development Framework (ANPDF) 2017-2021_8933f24fb14341efc0bbbc526071ea0d.pdf'}}]}}},
#      {'key': 'basic hydrogen strategy 10359',
#       'doc_count': 5,
#       'document_date': {'count': 5,
#        'min': 1483228800000.0,
#        'max': 1483228800000.0,
#        'avg': 1483228800000.0,
#        'sum': 7416144000000.0,
#        'min_as_string': '01/01/2017',
#        'max_as_string': '01/01/2017',
#        'avg_as_string': '01/01/2017',
#        'sum_as_string': '04/01/2205'},
#       'top_hit': {'value': 298.0492858886719},
#       'top_passage_hits': {'hits': {'total': {'value': 5, 'relation': 'eq'},
#         'max_score': 298.0493,
#         'hits': [{'_index': 'navigator',
#           '_type': '_doc',
#           '_id': 'ZQ3YBoEBdV_HkmO8gL70',
#           '_score': 298.0493,
#           '_source': {'document_instrument_name': 'Processes, plans and strategies|Governance',
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'East Asia & Pacific',
#            'document_description': "This document sets Japan's vision on how to achieve a hydrogen-based society by 2050 and provides an action plan for its realisation. It specifically seeks to decarbonise the energy, industry and transportation sectors.The Strategic Roadmap for Hydrogen and Fuel Cells defines 1) new targets on the specification of basic technologies and the breakdown of costs, 2) necessary measures for achieving these goals; and 3) that Japan will convene a working group consisting of experts to review the status of implementation in each area stipulated by the roadmap.",
#            'document_country_english_shortname': 'Japan',
#            'document_category': 'Policy',
#            'document_sector_name': ['Transportation', 'Industry', 'Energy'],
#            'md5_sum': 'c662e8efd1b8e5b70577b8a23cd97192',
#            'document_language': 'English',
#            'document_id': 10359,
#            'document_source_name': 'CCLW',
#            'document_name': 'Basic Hydrogen Strategy',
# ...
#            'document_country_english_shortname': 'Japan',
#            'document_category': 'Policy',
#            'document_sector_name': [],
#            'md5_sum': '1b62bb775fb077fa4cbd08492583743a',
#            'document_language': 'English',
#            'document_id': 12227,
#            'document_source_name': 'CCLW',
#            'document_name': 'Fundamental Plan for National Resilience',
#            'document_country_code': 'JPN',
#            'document_hazard_name': [],
#            'text': '4) Energy',
#            'document_response_name': ['Disaster Risk Management',
#             'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'East Asia & Pacific',
#            'text_block_id': 'p134_b2302',
#            'document_source_url': 'https://www.cas.go.jp/jp/seisaku/kokudo_kyoujinka/en/fundamental_plan.pdf',
#            'document_date': '14/12/2018',
#            'text_block_page': 134,
#            'text_block_coords': [[70.91999816894531, 760.0162963867188],
#             [121.2591552734375, 760.0162963867188],
#             [121.2591552734375, 776.1802978515625],
#             [70.91999816894531, 776.1802978515625]],
#            'document_name_and_id': 'Fundamental Plan for National Resilience 12227',
#            'document_keyword': ['Adaptation',
#             'Industry',
#             'Institutions / Administrative Arrangements',
#             'Buildings'],
#            'document_url': 'https://cdn.climatepolicyradar.org/JPN/2018/JPN-2018-12-14-Fundamental Plan for National Resilience_1b62bb775fb077fa4cbd08492583743a.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': 'hxEHB4EBdV_HkmO88qb0',
#           '_score': 205.03888,
#           '_source': {'document_instrument_name': ['Education, training and knowledge dissemination|Information',
#             'MRV|Governance',
#             'Early warning systems|Direct Investment'],
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'East Asia & Pacific',
#            'document_description': 'This plan defines four overarching principles governing resilience in Japan: preventing loss of life, maintaining state and society functions, minimizing property damage, and achieving swift recovery. The policies planned for by the Japanese government place special emphasis on combining "hard" and "soft" adaptation measures. Examples include developing disaster management facilities, resilient construction, emergency drills, and disaster management education. Additionally, this plan outlines procedures for conducting vulnerability assessments, different mechanisms for promoting resilience in different sectors and at different levels of government, and the process for reviewing national and subnational resilience plans.',
#            'document_country_english_shortname': 'Japan',
#            'document_category': 'Policy',
#            'document_sector_name': [],
#            'md5_sum': '1b62bb775fb077fa4cbd08492583743a',
#            'document_language': 'English',
#            'document_id': 12227,
#            'document_source_name': 'CCLW',
#            'document_name': 'Fundamental Plan for National Resilience',
#            'document_country_code': 'JPN',
#            'document_hazard_name': [],
#            'text': 'produced energy through the use of thermal energy, in light of medium- to long-term trends of',
#            'document_response_name': ['Disaster Risk Management',
#             'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'East Asia & Pacific',
#            'text_block_id': 'p34_b458',
#            'document_source_url': 'https://www.cas.go.jp/jp/seisaku/kokudo_kyoujinka/en/fundamental_plan.pdf',
#            'document_date': '14/12/2018',
#            'text_block_page': 34,
#            'text_block_coords': [[80.62800598144531, 239.7563018798828],
#             [527.4459533691406, 239.7563018798828],
#             [527.4459533691406, 455.9002990722656],
#             [80.62800598144531, 455.9002990722656]],
#            'document_name_and_id': 'Fundamental Plan for National Resilience 12227',
#            'document_keyword': ['Adaptation',
#             'Industry',
#             'Institutions / Administrative Arrangements',
#             'Buildings'],
#            'document_url': 'https://cdn.climatepolicyradar.org/JPN/2018/JPN-2018-12-14-Fundamental Plan for National Resilience_1b62bb775fb077fa4cbd08492583743a.pdf'}}]}}},
#      {'key': '12th five year plan (2018-2023) 10452',
#       'doc_count': 5,
#       'document_date': {'count': 5,
#        'min': 1545004800000.0,
#        'max': 1545004800000.0,
#        'avg': 1545004800000.0,
#        'sum': 7725024000000.0,
#        'min_as_string': '17/12/2018',
#        'max_as_string': '17/12/2018',
#        'avg_as_string': '17/12/2018',
#        'sum_as_string': '19/10/2214'},
#       'top_hit': {'value': 281.0796813964844},
#       'top_passage_hits': {'hits': {'total': {'value': 5, 'relation': 'eq'},
#         'max_score': 281.07968,
#         'hits': [{'_index': 'navigator',
#           '_type': '_doc',
#           '_id': 'SMUaB4EBLpAxSYvyVV_E',
#           '_score': 281.07968,
#           '_source': {'document_instrument_name': 'Processes, plans and strategies|Governance',
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'South Asia',
#            'document_description': 'This document was prepared by the Gross National Happiness Commission and aims at enabling a just, harmonious and sustainable society through enhanced decentralisation. It notably seeks to ensure adequate renewable energy supply, water, food and nutrition security, improved efficiency and effectiveness of public service delivery.<br><br>',
#            'document_country_english_shortname': 'Bhutan',
#            'document_category': 'Policy',
#            'document_sector_name': 'Economy-wide',
#            'md5_sum': '1edf263a6d05cabf008ecb0a9d9645fd',
#            'document_language': 'English',
#            'document_id': 10452,
#            'document_source_name': 'CCLW',
#            'document_name': '12th Five Year Plan (2018-2023)',
#            'document_country_code': 'BTN',
#            'document_hazard_name': [],
#            'text': '▀ Ensuring renewable energy supply,',
#            'document_response_name': ['Mitigation',
#             'Disaster Risk Management',
#             'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'South Asia',
#            'text_block_id': 'p40_b24',
#            'document_source_url': 'https://www.gnhc.gov.bt/en/wp-content/uploads/2019/05/TWELVE-FIVE-YEAR-WEB-VERSION.pdf',
#            'document_date': '17/12/2018',
#            'text_block_page': 40,
#            'text_block_coords': [[271.464, 283.4464],
#             [429.49699999999996, 283.4464],
#             [429.49699999999996, 292.399],
#             [271.464, 292.399]],
#            'document_name_and_id': '12th Five Year Plan (2018-2023) 10452',
#            'document_keyword': [],
#            'document_url': 'https://cdn.climatepolicyradar.org/BTN/2018/BTN-2018-12-17-12th Five Year Plan (2018-2023)_1edf263a6d05cabf008ecb0a9d9645fd.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': 'sGAaB4EBOM4u5WteXCwI',
#           '_score': 276.3058,
#           '_source': {'document_instrument_name': 'Processes, plans and strategies|Governance',
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'South Asia',
#            'document_description': 'This document was prepared by the Gross National Happiness Commission and aims at enabling a just, harmonious and sustainable society through enhanced decentralisation. It notably seeks to ensure adequate renewable energy supply, water, food and nutrition security, improved efficiency and effectiveness of public service delivery.<br><br>',
#            'document_country_english_shortname': 'Bhutan',
#            'document_category': 'Policy',
#            'document_sector_name': 'Economy-wide',
#            'md5_sum': '1edf263a6d05cabf008ecb0a9d9645fd',
#            'document_language': 'English',
#            'document_id': 10452,
#            'document_source_name': 'CCLW',
#            'document_name': '12th Five Year Plan (2018-2023)',
#            'document_country_code': 'BTN',
#            'document_hazard_name': [],
#            'text': 'renewable energy resources to supplement',
#            'document_response_name': ['Mitigation',
#             'Disaster Risk Management',
#             'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'South Asia',
#            'text_block_id': 'p70_b4',
#            'document_source_url': 'https://www.gnhc.gov.bt/en/wp-content/uploads/2019/05/TWELVE-FIVE-YEAR-WEB-VERSION.pdf',
#            'document_date': '17/12/2018',
#            'text_block_page': 70,
#            'text_block_coords': [[74.6929, 564.0666],
#             [249.03589999999997, 564.0666],
#             [249.03589999999997, 572.5376],
#             [74.6929, 572.5376]],
#            'document_name_and_id': '12th Five Year Plan (2018-2023) 10452',
#            'document_keyword': [],
#            'document_url': 'https://cdn.climatepolicyradar.org/BTN/2018/BTN-2018-12-17-12th Five Year Plan (2018-2023)_1edf263a6d05cabf008ecb0a9d9645fd.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': '8MUaB4EBLpAxSYvyVV7E',
#           '_score': 276.05164,
#           '_source': {'document_instrument_name': 'Processes, plans and strategies|Governance',
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'South Asia',
#            'document_description': 'This document was prepared by the Gross National Happiness Commission and aims at enabling a just, harmonious and sustainable society through enhanced decentralisation. It notably seeks to ensure adequate renewable energy supply, water, food and nutrition security, improved efficiency and effectiveness of public service delivery.<br><br>',
#            'document_country_english_shortname': 'Bhutan',
#            'document_category': 'Policy',
#            'document_sector_name': 'Economy-wide',
#            'md5_sum': '1edf263a6d05cabf008ecb0a9d9645fd',
#            'document_language': 'English',
#            'document_id': 10452,
#            'document_source_name': 'CCLW',
#            'document_name': '12th Five Year Plan (2018-2023)',
#            'document_country_code': 'BTN',
#            'document_hazard_name': [],
#            'text': '[7]Affordable and Clean Energy',
#            'document_response_name': ['Mitigation',
#             'Disaster Risk Management',
#             'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'South Asia',
#            'text_block_id': 'p35_b7',
#            'document_source_url': 'https://www.gnhc.gov.bt/en/wp-content/uploads/2019/05/TWELVE-FIVE-YEAR-WEB-VERSION.pdf',
#            'document_date': '17/12/2018',
#            'text_block_page': 35,
#            'text_block_coords': [[188.367, 497.456],
#             [277.568, 497.456],
#             [277.568, 504.337],
#             [188.367, 504.337]],
#            'document_name_and_id': '12th Five Year Plan (2018-2023) 10452',
#            'document_keyword': [],
#            'document_url': 'https://cdn.climatepolicyradar.org/BTN/2018/BTN-2018-12-17-12th Five Year Plan (2018-2023)_1edf263a6d05cabf008ecb0a9d9645fd.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': 'JcUaB4EBLpAxSYvyaGK-',
#           '_score': 274.891,
#           '_source': {'document_instrument_name': 'Processes, plans and strategies|Governance',
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'South Asia',
#            'document_description': 'This document was prepared by the Gross National Happiness Commission and aims at enabling a just, harmonious and sustainable society through enhanced decentralisation. It notably seeks to ensure adequate renewable energy supply, water, food and nutrition security, improved efficiency and effectiveness of public service delivery.<br><br>',
#            'document_country_english_shortname': 'Bhutan',
#            'document_category': 'Policy',
#            'document_sector_name': 'Economy-wide',
#            'md5_sum': '1edf263a6d05cabf008ecb0a9d9645fd',
#            'document_language': 'English',
#            'document_id': 10452,
#            'document_source_name': 'CCLW',
#            'document_name': '12th Five Year Plan (2018-2023)',
#            'document_country_code': 'BTN',
#            'document_hazard_name': [],
#            'text': '▀ Promoting green and energy efficient',
#            'document_response_name': ['Mitigation',
#             'Disaster Risk Management',
#             'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'South Asia',
#            'text_block_id': 'p108_b7',
#            'document_source_url': 'https://www.gnhc.gov.bt/en/wp-content/uploads/2019/05/TWELVE-FIVE-YEAR-WEB-VERSION.pdf',
#            'document_date': '17/12/2018',
#            'text_block_page': 108,
#            'text_block_coords': [[67.0394, 338.95439999999996],
#             [234.4764, 338.95439999999996],
#             [234.4764, 347.907],
#             [67.0394, 347.907]],
#            'document_name_and_id': '12th Five Year Plan (2018-2023) 10452',
#            'document_keyword': [],
#            'document_url': 'https://cdn.climatepolicyradar.org/BTN/2018/BTN-2018-12-17-12th Five Year Plan (2018-2023)_1edf263a6d05cabf008ecb0a9d9645fd.pdf'}},
#          {'_index': 'navigator',
#           '_type': '_doc',
#           '_id': 'sWAaB4EBOM4u5WteXCwI',
#           '_score': 270.40018,
#           '_source': {'document_instrument_name': 'Processes, plans and strategies|Governance',
#            'document_instrument_parent': [],
#            'document_region_english_shortname': 'South Asia',
#            'document_description': 'This document was prepared by the Gross National Happiness Commission and aims at enabling a just, harmonious and sustainable society through enhanced decentralisation. It notably seeks to ensure adequate renewable energy supply, water, food and nutrition security, improved efficiency and effectiveness of public service delivery.<br><br>',
#            'document_country_english_shortname': 'Bhutan',
#            'document_category': 'Policy',
#            'document_sector_name': 'Economy-wide',
#            'md5_sum': '1edf263a6d05cabf008ecb0a9d9645fd',
#            'document_language': 'English',
#            'document_id': 10452,
#            'document_source_name': 'CCLW',
#            'document_name': '12th Five Year Plan (2018-2023)',
#            'document_country_code': 'BTN',
#            'document_hazard_name': [],
#            'text': 'the national energy needs by harnessing',
#            'document_response_name': ['Mitigation',
#             'Disaster Risk Management',
#             'Adaptation'],
#            'document_type': 'Plan',
#            'document_framework_name': [],
#            'document_region_code': 'South Asia',
#            'text_block_id': 'p70_b5',
#            'document_source_url': 'https://www.gnhc.gov.bt/en/wp-content/uploads/2019/05/TWELVE-FIVE-YEAR-WEB-VERSION.pdf',
#            'document_date': '17/12/2018',
#            'text_block_page': 70,
#            'text_block_coords': [[74.6929, 551.067],
#             [237.1639, 551.067],
#             [237.1639, 559.538],
#             [74.6929, 559.538]],
#            'document_name_and_id': '12th Five Year Plan (2018-2023) 10452',
#            'document_keyword': [],
#            'document_url': 'https://cdn.climatepolicyradar.org/BTN/2018/BTN-2018-12-17-12th Five Year Plan (2018-2023)_1edf263a6d05cabf008ecb0a9d9645fd.pdf'}}]}}}]}}}}
